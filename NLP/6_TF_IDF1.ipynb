# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Sample documents
documents = [
    "I love machine learning",
    "Machine learning is fun",
    "I love Python"
]

# %%
# Create TF-IDF Vectorizer
tfidf=TfidfVectorizer()

# %% [markdown]
# fit_transform():
#
# fit:Learns the words (vocabulary),
#
# transform:convert text into numbers(vectors)

# %%
# Fit and transform documents
X=tfidf.fit_transform(documents)

# %%
# Print feature names
print("Words:")
print(tfidf.get_feature_names_out())
# Out:
# Words:
# ['fun' 'is' 'learning' 'love' 'machine' 'python']

# %%
# Print TF-IDF matrix
print("\nTF-IDF Matrix:")
print(X.toarray())
# Out:
# TF-IDF Matrix:
# [[0.         0.         0.57735027 0.57735027 0.57735027 0.        ]
#  [0.5628291  0.5628291  0.42804604 0.         0.42804604 0.        ]
#  [0.         0.         0.         0.60534851 0.         0.79596054]]
