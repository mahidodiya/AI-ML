# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\SHINE
# [nltk_data]     iNFOCARE\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to C:\Users\SHINE
# [nltk_data]     iNFOCARE\AppData\Roaming\nltk_data...
# True

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()

# %%
words = ["cars","children","mice","geese","feet","running","ran","better","best","worse","studies","studying","ate","eaten","eating","rocks","leaves","wolves","cities","knives","playing","played","plays","driving","drove","driven","writing","wrote","written"]

# %%
for word in words:
    print(word+"--->"+lemmatizer.lemmatize(word,pos='v'))
# Out:
# cars--->cars
# children--->children
# mice--->mice
# geese--->geese
# feet--->feet
# running--->run
# ran--->run
# better--->better
# best--->best
# worse--->worse
# studies--->study
# studying--->study
# ate--->eat
# eaten--->eat
# eating--->eat
# rocks--->rock
# leaves--->leave
# wolves--->wolves
# cities--->cities
# knives--->knives
# playing--->play
# played--->play
# plays--->play
# driving--->drive
# drove--->drive
# driven--->drive
# writing--->write
# wrote--->write
# written--->write
